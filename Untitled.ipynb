# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/Users/gsbhatia/Desktop/project_1/india-news-headlines.csv', index_col=None)

# %%
head_cat = df['headline_category'].unique()

# %%
count = 1
for head in head_cat:
    if("business" in head.lower()):
        count+=1
        print(head)
print(count)
# Out:
# business.india-business
# business.international-business
# business
# business.personal-finance
# business.markets
# best-of-the-week.india-business
# business.mf-simplified.faq
# business.mf-simplified.jargon-busters.equity
# business.mf-simplified.jargon-busters.debt
# business.mf-simplified.mf-news
# india-business-news-wire
# business.apahm.readers-corner
# india-business-news-wire.28-km
# business.faqs.aadhar-faqs
# business.faqs.pan-card-faqs
# business.faqs.insurance-faqs
# business.faqs.gst-faqs
# business.faqs.miscellaneous
# business.faqs.income-tax-faqs
# business.faqs.mutual-fund-faqs
# 21

# %%
cat = head_cat.tolist()

# %%
len(df["headline_category"].unique())
# Out:
# 1952

# %%
cat
# Out:
# ['sports.wwe',
#  'bollywood',
#  'unknown',
#  'entertainment.hindi.bollywood.news',
#  'business.india-business',
#  'city.bengaluru',
#  'city.delhi',
#  'city.patna',
#  'hollywood',
#  'india',
#  'sports.cricket.news',
#  'sports.football',
#  'only-in-america',
#  'city.ahmedabad',
#  'jugular-vein',
#  'swaminomics',
#  'city.thiruvananthapuram',
#  'city.chandigarh',
#  'city.mumbai',
#  'city.pune',
#  'home.science',
#  'city.kolkata',
#  'city.lucknow',
#  'city.hyderabad',
#  'cricket',
#  'business.international-business',
#  'removed',
#  'entertainment.english.hollywood.news',
#  'off-the-cuff',
#  'home.sunday-times.deep-focus',
#  'bombay-times',
#  'india-in-lanka',
#  'home.sunday-times.all-that-matters',
#  'talking-terms',
#  'home.education',
#  'pune-times',
#  'calcutta-times',
#  'hyderabad-times',
#  'bangalore-times',
#  'delhi-times',
#  'lucknow-times',
#  'ahmedabad-times',
#  'citizens-grievances',
#  'anti-terror-law',
#  'hyderabad.local-sports',
# ...

# %%
count = 1
for head in head_cat:
    if("delhi" in head.lower()):
        count+=1
        print(head)
print(count)
# Out:
# city.delhi
# delhi-times
# delhi-edition
# delhi
# cities.delhi
# cities.delhi-times
# delhi-ncr-pluses
# entertainment.events.delhi
# pearl-infrastructure-delhi-couture-week10.debate
# synergy1-delhi-couture-week11.show-schedule
# delhis-century
# assembly-elections-2013.delhi-assembly-elections
# delhi-ncr
# delhi-elections-2015
# delhi-elections-2015.party-stand.education
# litfest.litfest-delhi
# let-delhi-breathe-sign-up-to-save-delhi-from-choking
# delhi-ngo
# toi-green-drive-join-the-drive-to-help-delhi-breathe
# litfest.litfest-delhi.news
# entertainment.hindi.bollywood.news.feasts-movies-and-excursions-delhi
# tv.news.hindi.feasts-movies-and-excursions-delhi
# delhi-mass-suicide
# entertainment.events.delhi.times-lit-fest-2018-filmmakers-discuss-content-v
# 25

# %%
type(df['publish_date'][1])
# Out:
# numpy.int64

# %%
df['date']= pd.to_datetime(data['publish_date'])

# %%
news_df =df

# %%
stock_df = pd.read_csv('/Users/gsbhatia/Desktop/project_1/nse/Companies_list.csv', index_col=None)

# %%
c=0
cn=0
for name in stock_df["Name"]:
    name = name.split("_")
    if("Limited" not in name):
        c+=1
        print(name)
    else:
        cn+=1
        
print(c)
print(cn)
# Out:
# ['Allahabad', 'Bank']
# ['Andhra', 'Bank']
# ['Bank', 'of', 'Baroda']
# ['Bank', 'of', 'India']
# ['Canara', 'Bank']
# ['Central', 'Bank', 'of', 'India']
# ['Corporation', 'Bank']
# ['Dena', 'Bank']
# ['Diamond', 'Power', 'Infra', 'Ltd']
# ['Dishman', 'Pharmaceuticals', 'and', 'Chemicals']
# ['Godawari', 'Power', 'And', 'Ispat', 'limited']
# ['Gujarat', 'State', 'Financial', 'Corporation']
# ['Indian', 'Bank']
# ['Indian', 'Overseas', 'Bank']
# ['Kandagiri', 'Spinning', 'Mills', 'Limited.']
# ['Bank', 'of', 'Maharashtra']
# ['State', 'Bank', 'of', 'Mysore']
# ['Oriental', 'Bank', 'of', 'Commerce']
# ['Punjab', 'National', 'Bank']
# ['Punjab', '&', 'Sind', 'Bank']
# ['State', 'Bank', 'of', 'Bikaner', 'and', 'Jaipur']
# ['State', 'Bank', 'of', 'India']
# ['State', 'Bank', 'of', 'Travancore']
# ['Seshasayee', 'Paper', 'and', 'Boards', 'Limi']
# ['Syndicate', 'Bank']
# ['UCO', 'Bank']
# ['Union', 'Bank', 'of', 'India']
# ['United', 'Bank', 'of', 'India']
# ['Vijaya', 'Bank']
# 29
# 1355

# %%
idx = 0
for name in stock_df["Name"]:
        if("d b" in name.lower()):
            print(name)

# %%
stock_df
# Out:
#       Unnamed: 0      Symbol                                            Name
# 0              0   20MICRONS                              20_Microns_Limited
# 1              1  3IINFOTECH                             3i_Infotech_Limited
# 2              2     3MINDIA                                3M_India_Limited
# 3              3      A2ZMES  A2Z_Maintenance_&_Engineering_Services_Limited
# 4              4   AANJANEYA                      Aanjaneya_Lifecare_Limited
# ...          ...         ...                                             ...
# 1379        1379  ZODIACLOTH                 Zodiac_Clothing_Company_Limited
# 1380        1380   ZODJRDMKJ                         Zodiac_JRD-_MKJ_Limited
# 1381        1381   ZUARIAGRO                        Zuari_Industries_Limited
# 1382        1382   ZYDUSWELL                          Zydus_Wellness_Limited
# 1383        1383       ZYLOG                           Zylog_Systems_Limited
#
# [1384 rows x 3 columns]

# %%
for name in stock_df["Symbol"]:
    if(name.lower()=="adag"):
        print(name)

# %%
stock_df
# Out:
#       Unnamed: 0      Symbol                                            Name
# 0              0   20MICRONS                              20_Microns_Limited
# 1              1  3IINFOTECH                             3i_Infotech_Limited
# 2              2     3MINDIA                                3M_India_Limited
# 3              3      A2ZMES  A2Z_Maintenance_&_Engineering_Services_Limited
# 4              4   AANJANEYA                      Aanjaneya_Lifecare_Limited
# ...          ...         ...                                             ...
# 1379        1379  ZODIACLOTH                 Zodiac_Clothing_Company_Limited
# 1380        1380   ZODJRDMKJ                         Zodiac_JRD-_MKJ_Limited
# 1381        1381   ZUARIAGRO                        Zuari_Industries_Limited
# 1382        1382   ZYDUSWELL                          Zydus_Wellness_Limited
# 1383        1383       ZYLOG                           Zylog_Systems_Limited
#
# [1384 rows x 3 columns]

# %%
mylist = ["aa","bb"]
" ".join(mylist)
# Out:
# 'aa bb'

# %%
" A B".lower()
# Out:
# ' a b'

# %%
import unicodedata

def uni_to_string(name):
	return unicodedata.normalize('NFKD', name).encode('ascii','ignore')

# %%
x = u'"get"'
type(x)
# Out:
# str

# %%
x.replace('"','')
# Out:
# 'get'

# %%
head = "yes"
tar = ['yes',"no", "ab"]
head in tar
# Out:
# True

# %%
name = "madhav marbles and granites"
headline = "madhav marbles"

# %%
def check_name_in_headline(name,headline):
        name = name.split(" ")
        name = " ".join(name[0:2])
        print(name)

# %%
check_name_in_headline(name,headline)
# Out:
# madhav marbles

# %%
stock_df = pd.read_csv('/Users/gsbhatia/Desktop/project_1/nse/historical_data/WIPRO_data.csv', index_col=None)

# %%
stock_df.count()
# Out:
# Date         4854
# open         4791
# high         4791
# low          4791
# close        4791
# adj_close    4791
# volume       4791
# dtype: int64

# %%
4854/365
# Out:
# 13.2986301369863
